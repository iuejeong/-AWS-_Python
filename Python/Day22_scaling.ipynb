# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

url = 'https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt'
pd_data = pd.read_csv(url, sep = '\t')
print(pd_data.head())
print(pd_data.shape)
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135
# (442, 11)

# %%
_, axe = plt.subplots()
axe.plot(pd_data['BMI'])
axe.plot(pd_data['BP'])

# %%
# normalization   :   (x - x_min) / x_max - x_min
# standardization을 사용했을 때, 적절하지 않을 경우 normalzation을 사용한다.
pd_data['BMI'].describe()
bmi_min = pd_data['BMI'].min()
bmi_max = pd_data['BMI'].max()
pd_data['BMI_norm'] = pd_data['BMI'].apply(lambda x: (x - bmi_min) / (bmi_max - bmi_min))
print(pd_data)
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y  \
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
#      BMI_norm
# 0    0.582645
# 1    0.148760
# 2    0.516529
# 3    0.301653
# 4    0.206612
# ..        ...
# 437  0.421488
# 438  0.285124
# 439  0.285124
# 440  0.495868
# 441  0.066116
#
# [442 rows x 12 columns]

# %%
pd_data['BP'].describe()
bp_min = pd_data['BP'].min()
bp_max = pd_data['BP'].max()
pd_data['BP_norm'] = pd_data['BP'].apply(lambda x: (x - bp_min) / (bp_max - bp_min))
print(pd_data)
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y  \
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
#      BMI_norm   BP_norm
# 0    0.582645  0.549296
# 1    0.148760  0.352113
# 2    0.516529  0.436620
# 3    0.301653  0.309859
# 4    0.206612  0.549296
# ..        ...       ...
# 437  0.421488  0.704225
# 438  0.285124  0.183099
# 439  0.285124  0.530563
# 440  0.495868  0.464789
# 441  0.066116  0.126761
#
# [442 rows x 13 columns]

# %%
_, axe = plt.subplots()
axe.plot(pd_data['BMI_norm'])
axe.plot(pd_data['BP_norm'])

# %%
# standardization: (x - x_mean) / x_std
# - 데이터 분포가 노멀커브(벨커브)를 따를 때.

pd_data['BMI'].describe()
bmi_mean = pd_data['BMI'].mean()
bmi_std = pd_data['BMI'].std()
pd_data['BMI_std'] = pd_data['BMI'].apply(lambda x: (x - bmi_mean) / bmi_std)

pd_data['BP'].describe()
bp_mean = pd_data['BP'].mean()
bp_std = pd_data['BP'].std()
pd_data['BP_std'] = pd_data['BP'].apply(lambda x: (x - bp_mean) / bp_std)

print(pd_data)
_, axe = plt.subplots()
axe.plot(pd_data['BMI_norm'])
axe.plot(pd_data['BP_norm'])
axe.plot(pd_data['BMI_std'])
axe.plot(pd_data['BP_std'])

print(pd_data['BP_norm'].describe())
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y  \
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
#      BMI_norm   BP_norm   BMI_std    BP_std
# 0    0.582645  0.549296  1.295620  0.459320
# 1    0.148760  0.352113 -1.080955 -0.552878
# 2    0.516529  0.436620  0.933475 -0.119079
# 3    0.301653  0.309859 -0.243495 -0.769778
# 4    0.206612  0.549296 -0.764079  0.459320
# ..        ...       ...       ...       ...
# 437  0.421488  0.704225  0.412892  1.254619
# 438  0.285124  0.183099 -0.334032 -1.420477
# 439  0.285124  0.530563 -0.334032  0.363161
# 440  0.495868  0.464789  0.820305  0.025521
# 441  0.066116  0.126761 -1.533636 -1.709676
#
# [442 rows x 15 columns]
# count    442.000000
# mean       0.459817
# std        0.194807
# min        0.000000
# 25%        0.309859
# 50%        0.436620
# 75%        0.605634
# max        1.000000
# Name: BP_norm, dtype: float64
