# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
r = plt.plot(xs, ys)
print(r)

# %%
xs = np.linspace(0, 50, 100)
ys = np.sin(xs)

# print(xs)
# print(ys)

figure, axe = plt.subplots()
# figure.set_facecolor('blue')
# axe.set_facecolor('red')
# figure.suptitle('Figure1')
# figure.supxlabel('Figure1_x')
# figure.supylabel('Figure1_y')
# figure.text(0.8, 0.85, 'iuejeong')
# figure.set_size_inches(15, 4.8)

axe.plot(xs, ys)
# axe.set_title('my axe title')
# axe.set_xlabel('axe_x')
# axe.set_ylabel('axe_y')
# axe.set_xlim(0, 30)
# axe.set_ylim(-10, 10)
# axe.set_xticks(list(np.linspace(0, 30, 6)))
# axe.set_xticklabels(list('abcdef'))
print(type(figure))        # figure = 도화지
print(type(axe))           # axe = 새까만 선 안에 있는 것들
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig, axe = plt.subplots(2, 3, sharey = True, figsize = (15, 7))
axe[1, 2].plot(xs, ys)

# %%
# fig1 = matplotlib.figure.Figure(figsize = [15, 7])
fig1 = plt.figure(figsize = [15, 7])

a = fig1.add_axes([10, 10, 1, 1])
a.plot(xs, ys)
# ([1. x축에서 얼만큼 왔다갔다 하는지, 2. y축에서 얼만큼 왔다갔다 하는지])
#([3. x축에서 크기가 얼마나 커졌다 작아지는지, 4. y축에서 크기가 얼마나 커졌다 작아지는지.)
b = fig1.add_axes([0.5, 0.3, 0.1, 0.5])         
b.plot(xs, ys)

# %%
fig2 = plt.figure(figsize = (15, 7))
# (2 = y축을 전체에서 몇 등분을 할 것인지, 2 = x축을 전체에서 몇 등분 할 것인지, 2 = 4개 중에 어느 번째에 들어갈 것인지.)
a = fig2.add_subplot(2, 2, 2)               
b = fig2.add_subplot(2, 2, 3)
c = fig2.add_subplot(2, 2, 4)
d = fig2.add_subplot(2, 2, 1)

# %%
fig3 = plt.figure(figsize = (15, 7))
f1 = fig3.add_subplot(3, 2, 1)
f2 = fig3.add_subplot(3, 2, 2)
f3 = fig3.add_subplot(3, 1, 2)
f4 = fig3.add_subplot(3, 2, 5)
f5 = fig3.add_subplot(3, 2, 6)

fig3.savefig('fig3.png')
